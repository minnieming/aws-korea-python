# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "J_sgS7UdTevi4mWa1j2R" #네이버 개발자 발급받은 아이디
client_secret = "tNt5mgUIuQ" #네이버 개발자 발급받은 시크릿키
encText = urllib.parse.quote("AWS")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + '&display=100' # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 25 Sep 2025 17:15:03 +0900",
# 	"total":207454,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"포스코DX 주가 전망｜아마존 <b>AWS<\/b> 동맹 후 실적발표가 말해준... ",
# 			"link":"https:\/\/blog.naver.com\/press02\/224006850238",
# 			"description":"포스코DX 주가 전망, 아마존 <b>AWS<\/b> 협력 이후 달라진 흐름을 짚어봅니다. 2분기 실적발표와 차트분석... 아마존 <b>AWS<\/b>와 손잡은 포스코DX가 현장 엔지니어의 손을 덜어주는 AI 엔지니어 에이전트와 PLC 코파일럿을... ",
# 			"bloggername":"재미진 저널리스트의 금융탐구생활",
# 			"bloggerlink":"blog.naver.com\/press02",
# 			"postdate":"20250914"
# 		},
# 		{
# 			"title":"클라우드 컴퓨팅 개요: <b>AWS<\/b> vs Azure vs GCP 비교",
# 			"link":"https:\/\/blog.naver.com\/sanjose700\/224019863082",
# 			"description":"클라우드 컴퓨팅 개요: <b>AWS<\/b> vs Azure vs GCP 비교  안녕하세요! 오늘은 많은 기업과 개인 개발자들이... 특히 전 세계적으로 가장 많이 사용되는 대표 클라우드 서비스인 <b>AWS<\/b>, Azure, GCP를 비교하면서 각각의... ",
# 			"bloggername":"전사랑 전통부침개 전문점",
# 			"bloggerlink":"blog.naver.com\/sanjose700",
# 			"postdate":"20250924"
# 		},
# 		{
# ...

# %%
import json

response_body = json.loads(response_body.decode('utf-8'))

# %%
response_body
# Out:
# {'lastBuildDate': 'Thu, 25 Sep 2025 17:15:03 +0900',
#  'total': 207454,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '포스코DX 주가 전망｜아마존 <b>AWS</b> 동맹 후 실적발표가 말해준... ',
#    'link': 'https://blog.naver.com/press02/224006850238',
#    'description': '포스코DX 주가 전망, 아마존 <b>AWS</b> 협력 이후 달라진 흐름을 짚어봅니다. 2분기 실적발표와 차트분석... 아마존 <b>AWS</b>와 손잡은 포스코DX가 현장 엔지니어의 손을 덜어주는 AI 엔지니어 에이전트와 PLC 코파일럿을... ',
#    'bloggername': '재미진 저널리스트의 금융탐구생활',
#    'bloggerlink': 'blog.naver.com/press02',
#    'postdate': '20250914'},
#   {'title': '클라우드 컴퓨팅 개요: <b>AWS</b> vs Azure vs GCP 비교',
#    'link': 'https://blog.naver.com/sanjose700/224019863082',
#    'description': '클라우드 컴퓨팅 개요: <b>AWS</b> vs Azure vs GCP 비교  안녕하세요! 오늘은 많은 기업과 개인 개발자들이... 특히 전 세계적으로 가장 많이 사용되는 대표 클라우드 서비스인 <b>AWS</b>, Azure, GCP를 비교하면서 각각의... ',
#    'bloggername': '전사랑 전통부침개 전문점',
#    'bloggerlink': 'blog.naver.com/sanjose700',
#    'postdate': '20250924'},
#   {'title': '인프라 엔지니어 <b>AWS</b> 학원 교육 정보',
# ...

# %%
import pandas as pd

df = pd.DataFrame(response_body['items'])
df.reset_index(drop=True, inplace=True)

df.to_csv("./ch04/naver_blog_search_AWS.csv", index=False) #저장할때 이렇게 한다

# %% [markdown]
# ## 네이버 검색 : 책

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "J_sgS7UdTevi4mWa1j2R" #네이버 개발자 발급받은 아이디
client_secret = "tNt5mgUIuQ" #네이버 개발자 발급받은 시크릿키
encText = urllib.parse.quote("클라우드")
url = "https://openapi.naver.com/v1/search/book?query=" + encText + '&display=100' # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 25 Sep 2025 17:27:41 +0900",
# 	"total":440,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"만화의 이해",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32483329173",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3248332\/32483329173.20230919130230.jpg",
# 			"author":"스콧 맥클라우드",
# 			"discount":"17100",
# 			"publisher":"비즈앤비즈",
# 			"pubdate":"20080701",
# 			"isbn":"9788992607148",
# 			"description":"가장 잘 만들어진 만화 이론서라는 평가를 받고 있는 『만화의 이해』는 만화에 대한 단순한 이해를 뛰어넘어 만화의 정체성과 예술성, 그 정의와 영역에 대한 심도 깊은 논의를 펼치고 있어, 비단 만화에만 국한되는 것이 아닌 대중예술 전반에 대한 오해와 편견을 벗겨 내주기에 충분하다. 만화 이론가이자 만화가인 저자는 매우 친절하고 진지하게 만화의 내부구조를 설명하고 있어, 만화의 칸과 칸 사이의 공간도 그냥 지나치지 않는 저자의 예리한 시각은 곧 전세계 독자들의 열광적인 호응으로 이어졌다. \n\n만화는 언어의 일종이자 폭넓은 범주의 시각적 상징들이며 독자는 칸 사이에 있는 공간을 통해 정지된 그림을 살아 움직이게 만든다는 등의 내용이 담겨 있다. 심각하게, 그리고 무자비하게 홀대 받아온 만화라는 장르를 분명하고도 단호한 어조로 '예술'이라고 평가하고 있다. 만화의 형식을 빌어 만화를 설명하는, 가장 만화다우면서 만화를 위한 책이다."
# 		},
# 		{
# 			"title":"클라우드 나인",
# ...
